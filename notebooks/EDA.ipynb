# %%
import pandas as pd
import numpy as np
import os, sys

os.getcwd()
rpath = os.path.abspath('../')
if rpath not in sys.path:
    sys.path.insert(0,rpath)

# Load the .txt file
# Construct the file path
file_path = os.path.join(rpath, 'data', 'MachineLearningRating_v3.txt')

# Skip lines with too many fields
# Try with different delimiters
data = pd.read_csv(file_path, delimiter='|')  # Tab-delimited
data.head()
# Out:
# C:\Users\AII\AppData\Local\Temp\ipykernel_14720\1257161550.py:16: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, delimiter='|')  # Tab-delimited
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# ...

# %%
data.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
data['VehicleIntroDate'] = (pd.to_datetime(data['VehicleIntroDate'])) #.dt.date
# Out:
# C:\Users\AII\AppData\Local\Temp\ipykernel_14720\2765261463.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['VehicleIntroDate'] = (pd.to_datetime(data['VehicleIntroDate'])) #.dt.date

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
# ...

# %%
data.describe()
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# min        1.987000e+03       0.000000       0.000000       0.000000
# ...

# %%
data.isnull().sum()
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# ...

# %%
def handeling_missing_data(data):
    data.replace([np.inf, -np.inf], np.nan, inplace=True)
    missing_data = data.isnull().sum().sort_values(ascending=False)
    missing_percentage = (missing_data / len(data)) * 100
    data_cleaned = data.drop(columns=missing_data[missing_percentage > 90].index)

    # Step 3: Impute missing values in numeric columns using the mean
    numeric_cols = data_cleaned.select_dtypes(include=['float64', 'int64']).columns
    data_cleaned[numeric_cols] = data_cleaned[numeric_cols].fillna(0)

    # Step 4: Impute missing values in categorical columns using 'unknown'
    categorical_cols = data_cleaned.select_dtypes(include=['object']).columns
    data_cleaned[categorical_cols] = data_cleaned[categorical_cols].fillna('unknown')
    return data_cleaned

# %%
data_cleaned = handeling_missing_data(data)
data_cleaned.isnull().sum()
# Out:
# UnderwrittenCoverID           0
# PolicyID                      0
# TransactionMonth              0
# IsVATRegistered               0
# Citizenship                   0
# LegalType                     0
# Title                         0
# Language                      0
# Bank                          0
# AccountType                   0
# MaritalStatus                 0
# Gender                        0
# Country                       0
# Province                      0
# PostalCode                    0
# MainCrestaZone                0
# SubCrestaZone                 0
# ItemType                      0
# mmcode                        0
# VehicleType                   0
# RegistrationYear              0
# make                          0
# Model                         0
# Cylinders                     0
# cubiccapacity                 0
# kilowatts                     0
# bodytype                      0
# NumberOfDoors                 0
# VehicleIntroDate            552
# ...

# %%
# Descriptive statistics for numerical columns
numerical_cols = ['TotalClaims', 'TotalPremium', 'SumInsured', 'CalculatedPremiumPerTerm']
data_cleaned[numerical_cols].describe()
# Out:
#         TotalClaims  TotalPremium    SumInsured  CalculatedPremiumPerTerm
# count  1.000098e+06  1.000098e+06  1.000098e+06              1.000098e+06
# mean   6.486119e+01  6.190550e+01  6.041727e+05              1.178757e+02
# std    2.384075e+03  2.302845e+02  1.508332e+06              3.997017e+02
# min   -1.200241e+04 -7.825768e+02  1.000000e-02              0.000000e+00
# 25%    0.000000e+00  0.000000e+00  5.000000e+03              3.224800e+00
# 50%    0.000000e+00  2.178333e+00  7.500000e+03              8.436900e+00
# 75%    0.000000e+00  2.192982e+01  2.500000e+05              9.000000e+01
# max    3.930921e+05  6.528260e+04  1.263620e+07              7.442217e+04

# %%
# Summary of categorical variables
categorical_cols = ['Citizenship', 'VehicleType', 'CoverType', 'Gender']
for col in categorical_cols:
    print(f"{col} value counts:\n{data_cleaned[col].value_counts()}\n")
# Out:
# Citizenship value counts:
# Citizenship
#       895210
# ZA    103721
# ZW       936
# AF       231
# Name: count, dtype: int64
#
# VehicleType value counts:
# VehicleType
# Passenger Vehicle    933598
# Medium Commercial     53985
# Heavy Commercial       7401
# Light Commercial       3897
# Bus                     665
# unknown                 552
# Name: count, dtype: int64
#
# CoverType value counts:
# CoverType
# Own Damage                                             104183
# Passenger Liability                                    104158
# Windscreen                                             103763
# Third Party                                            102825
# Keys and Alarms                                        102428
# Signage and Vehicle Wraps                              102416
# Emergency Charges                                      102416
# Cleaning and Removal of Accident Debris                102414
# Income Protector                                        64813
# ...

# %%
# Convert to categorical type
data_cleaned['Citizenship'] = data_cleaned['Citizenship'].astype('category')
data_cleaned['VehicleType'] = data_cleaned['VehicleType'].astype('category')

# %%
# Check for duplicates
data_cleaned.duplicated().sum()

# Remove duplicates
data_cleaned = data_cleaned.drop_duplicates()

# %%
data_cleaned['ClaimToPremiumRatio'] = data_cleaned['TotalClaims'] / data_cleaned['TotalPremium']
data_cleaned.head()
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ... CoverCategory   CoverType            CoverGroup  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Identify numerical and categorical columns
numerical_columns = data_cleaned.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = data_cleaned.select_dtypes(include=['object', 'bool']).columns

# Plot histograms for numerical columns
def plot_histograms(df, columns):
    df[columns].hist(figsize=(15, 10), bins=30, color='skyblue', edgecolor='black')
    plt.suptitle('Histograms of Numerical Features', size=16)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# Plot bar charts for categorical columns
def plot_bar_charts(df, columns):
    fig, axes = plt.subplots(len(columns), 1, figsize=(10, len(columns)*5))
    for i, column in enumerate(columns):
        if df[column].nunique() < 20:  # Plot bar charts only for columns with fewer than 20 unique values
            sns.countplot(x=column, data_cleaned=df, ax=axes[i], palette='Set2')
            axes[i].set_title(f'Distribution of {column}', size=14)
            axes[i].set_ylabel('Count')
            axes[i].set_xlabel(column)
            axes[i].tick_params(axis='x', rotation=45)
    plt.tight_layout()
    plt.show()

# Call the functions
plot_histograms(data_cleaned, numerical_columns)
plot_bar_charts(data_cleaned, categorical_columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 29
#      26     plt.show()
#      28 # Call the functions
# ---> 29 plot_histograms(data_cleaned, numerical_columns)
#      30 plot_bar_charts(data_cleaned, categorical_columns)
#
# Cell In[32], line 10, in plot_histograms(df, columns)
#       9 def plot_histograms(df, columns):
# ---> 10     df[columns].hist(figsize=(15, 10), bins=30, color='skyblue', edgecolor='black')
#      11     plt.suptitle('Histograms of Numerical Features', size=16)
#      12     plt.tight_layout(rect=[0, 0, 1, 0.95])
#
# File c:\Users\AII\Desktop\historical-insurance-data-analysis\venv\lib\site-packages\pandas\plotting\_core.py:251, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     164 """
# ...

# %%
# Ensure the required columns are numerical
data_cleaned[['TotalPremium', 'TotalClaims']] = data_cleaned[['TotalPremium', 'TotalClaims']].apply(pd.to_numeric, errors='coerce')

# Drop rows with missing or NaN values for TotalPremium, TotalClaims, and PostalCode
data_cleaned = data_cleaned.dropna(subset=['TotalPremium', 'TotalClaims', 'PostalCode'])

# Convert PostalCode to a categorical variable if needed
data_cleaned['PostalCode'] = data_cleaned['PostalCode'].astype(str)

# Scatter plot: TotalPremium vs. TotalClaims as a function of PostalCode
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data_cleaned, x='TotalPremium', y='TotalClaims', hue='PostalCode', palette='viridis', s=100, alpha=0.7)
plt.title('Scatter Plot of TotalPremium vs. TotalClaims by PostalCode', size=16)
plt.xlabel('Total Premium', size=14)
plt.ylabel('Total Claims', size=14)
plt.legend(title='Postal Code', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# Calculate the correlation matrix
correlation_matrix = data_cleaned[['TotalPremium', 'TotalClaims']].corr()

# Plot correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix: TotalPremium and TotalClaims', size=16)
plt.show()

# %%
# Plot 1: Compare CoverType distribution over PostalCode
plt.figure(figsize=(10, 6))
sns.countplot(data=data_cleaned, x='PostalCode', hue='CoverType', palette='Set1')
plt.title('Distribution of CoverType Across Postal Codes', size=16)
plt.xlabel('Postal Code', size=14)
plt.ylabel('Count', size=14)
plt.xticks(rotation=45)
plt.legend(title='Cover Type')
plt.tight_layout()
plt.show()

# Plot 2: Compare Calculated Premium per Term across PostalCodes
plt.figure(figsize=(10, 6))
sns.boxplot(data=data_cleaned, x='PostalCode', y='CalculatedPremiumPerTerm', palette='Set2')
plt.title('Comparison of Premium per Term Across Postal Codes', size=16)
plt.xlabel('Postal Code', size=14)
plt.ylabel('Calculated Premium per Term', size=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot 3: Compare AutoMake across PostalCodes
plt.figure(figsize=(10, 6))
sns.countplot(data=data_cleaned, x='PostalCode', hue='Make', palette='Set3')
plt.title('Distribution of Auto Make Across Postal Codes', size=16)
plt.xlabel('Postal Code', size=14)
plt.ylabel('Count', size=14)
plt.xticks(rotation=45)
plt.legend(title='Auto Make', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\AII\AppData\Local\Temp\ipykernel_14720\2200829668.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data_cleaned, x='PostalCode', y='CalculatedPremiumPerTerm', palette='Set2')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 24
#      22 # Plot 3: Compare AutoMake across PostalCodes
#      23 plt.figure(figsize=(10, 6))
# ---> 24 sns.countplot(data=data_cleaned, x='PostalCode', hue='Make', palette='Set3')
#      25 plt.title('Distribution of Auto Make Across Postal Codes', size=16)
#      26 plt.xlabel('Postal Code', size=14)
#
# ...

# %%
# Box Plot for detecting outliers in TotalPremium and TotalClaims
plt.figure(figsize=(10, 6))
sns.boxplot(data=data_cleaned[['TotalPremium', 'TotalClaims']], palette='Set2')
plt.title('Box Plot for TotalPremium and TotalClaims', size=16)
plt.ylabel('Value', size=14)
plt.tight_layout()
plt.show()

# Box Plot for Calculated Premium per Term to detect outliers
plt.figure(figsize=(10, 6))
sns.boxplot(data=data_cleaned, y='CalculatedPremiumPerTerm', palette='Set1')
plt.title('Box Plot for CalculatedPremiumPerTerm', size=16)
plt.ylabel('Calculated Premium per Term', size=14)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\AII\AppData\Local\Temp\ipykernel_14720\950214313.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data_cleaned, y='CalculatedPremiumPerTerm', palette='Set1')

# %%
# Heatmap of correlations
plt.figure(figsize=(10, 8))
sns.heatmap(data_cleaned.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap of Numerical Variables', size=16)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.violinplot(data=data_cleaned, x='CoverType', y='CalculatedPremiumPerTerm', palette='muted')
plt.title('Distribution of CalculatedPremiumPerTerm by CoverType', size=16)
plt.xlabel('Cover Type', size=14)
plt.ylabel('Calculated Premium per Term', size=14)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
sns.stripplot(data=data_cleaned, x='PostalCode', y='TotalPremium', jitter=True, hue='CoverType', palette='Set2', dodge=True)
plt.title('Geographical Distribution of TotalPremium by CoverType', size=16)
plt.xlabel('Postal Code', size=14)
plt.ylabel('Total Premium', size=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 3
#       1 # Heatmap of correlations
#       2 plt.figure(figsize=(10, 8))
# ----> 3 sns.heatmap(data_cleaned.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
#       4 plt.title('Correlation Heatmap of Numerical Variables', size=16)
#       5 plt.tight_layout()
#
# File c:\Users\AII\Desktop\historical-insurance-data-analysis\venv\lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# ...
